# %% [markdown]
# <a href="https://colab.research.google.com/github/Yaminicetty/PythonNew/blob/Module-4/MATPLOTLIB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0, 10])
ypoints = np.array([0, 300])
plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["Beee", "Maths", "C", "English"])
y = np.array([50, 100, 65, 70])
plt.bar(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["Beee", "Maths", "C", "English"])
y = np.array([500, 1000, 650, 700])
plt.barh(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["python", "chemistry", "physics", "english"])
y = np.array([50, 100, 65, 70])
plt.bar(x, y, color = "pink")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([7, 9, 10, 11])
plt.plot(ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([7, 20, 31, 60])
plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([200, 725, 565, 815])
plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([10, 50, 75, 60 ,20])
mylabels = ["monday", "tuesday", "wednesday", "thursday","friday"]
plt.pie(y, labels = mylabels)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([23, 12, 25, 27])
mylabels = ["Maths", "English", "Physics", "Chemistry"]
myexplode= [0.2,0.2,0.2,0.2]
plt.pie(y, labels = mylabels, explode = myexplode, startangle = 90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([7, 4, 5, 2])

plt.plot(ypoints, marker = 'o')
plt.show()

# %%
...
plt.plot(ypoints, marker = '*')
...
# Out:
# Ellipsis

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 6, 4, 4])

plt.plot(ypoints, '*:b')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 6, 9, 10])

plt.plot(ypoints, marker = 'o', ms = 10)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([31, 48, 12, 34])

plt.plot(ypoints, marker = '*', ms = 30, mec = 'b')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 5, 4, 6])

plt.plot(ypoints, marker = 'o', ms = 15, mfc = 'black')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 5, 4, 6])


plt.plot(ypoints, marker = '*', ms = 40, mec = 'r', mfc = 'b')
plt.show()

# %%
...
plt.plot(ypoints, marker = '*', ms = 20, mec = '#4CAF50', mfc = '#4CAF50')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, marker = 'o', ms = 20, mec = 'hotpink', mfc = 'hotpink')
...
# Out:
# Ellipsis

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 3])
ypoints = np.array([0, 12])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0, 10])
ypoints = np.array([5, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([5, 10, 15, 20])

plt.plot(ypoints, color = 'r')
plt.show()

# %%
...
plt.plot(ypoints, c = '#4CAF50')
...
# Out:
# Ellipsis

# %%
...
plt.plot(ypoints, c = 'hotpink')
...
# Out:
# Ellipsis

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([2, 5, 4, 6])

plt.plot(ypoints, linewidth = '15.5')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y1 = np.array([3, 8, 1, 2])
y2 = np.array([6, 5, 7, 11])

plt.plot(y1)
plt.plot(y2)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x1 = np.array([0, 1, 2, 9])
y1 = np.array([3, 8, 9, 10])
x2 = np.array([3, 1, 2, 5])
y2 = np.array([5, 2, 7, 32])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([229, 230, 231, 232, 233, 234, 335, 336, 337, 338])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([229, 230, 231, 232, 233, 234, 335, 336, 337, 338])

plt.plot(x, y)

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([70, 75, 80, 85, 90, 95, 100, 105, 110, 115])
y = np.array([540, 550, 560, 570, 580, 590, 600, 610, 620, 630])

font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([70, 75, 80, 85, 90, 95, 100, 105, 110, 115])
y = np.array([540, 550, 560, 570, 580, 590, 600, 610, 620, 630])

plt.title("Sports Watch Data", loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([70, 75, 80, 85, 90, 95, 100, 105, 110, 115])
y = np.array([540, 550, 560, 570, 580, 590, 600, 610, 620, 630])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([70, 75, 80, 85, 90, 95, 100, 105, 110, 115])
y = np.array([540, 550, 560, 570, 580, 590, 600, 610, 620, 630])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'x')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([70, 75, 80, 85, 90, 95, 100, 105, 110, 115])
y = np.array([540, 550, 560, 570, 580, 590, 600, 610, 620, 630])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color = 'green', linestyle = '--', linewidth = 0.5)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([80, 25, 72, 93])
y = np.array([3, 58, 15, 70])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 40, 90])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 38, 14, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([230, 61, 92, 3])
y = np.array([10, 34, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 13, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([90, 14, 52, 73])
y = np.array([34, 18, 16, 40])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 70, 80, 90])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")

plt.suptitle("MY SHOP")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,4,11,12,9,6])
y = np.array([99,86,86,103,87,94,78,77,85,86])

plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,11,4,7,14,12])
y = np.array([100,105,84,105,90,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,6])
y = np.array([99,86,87,94,78,77,85,86])
plt.scatter(x, y, color = 'hotpink')

x = np.array([2,2,83,11,4,7,14,12])
y = np.array([100,105,84,79,112,91,80,85])
plt.scatter(x, y, color = '#88c999')

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([53,71,82,37,25,47,28,9,4,6])
y = np.array([99,86,87,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","purple","beige","brown","gray","cyan","magenta"])

plt.scatter(x, y, c=colors)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,2,9,6])
y = np.array([99,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([5,7,8,7,2,17,11,12,9,6])
y = np.array([88,111,86,103,87,94,78,77,85,86])
sizes = np.array([20,50,100,60,90,10,300,600,800,75])

plt.scatter(x, y, s=sizes, alpha=0.5)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(58, size=(90))
y = np.random.randint(10, size=(90))
colors = np.random.randint(170, size=(90))
sizes = 10 * np.random.randint(50, size=(90))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.normal(40, 70, 230)

plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["maths", "english", "C", "chemistry"])
y = np.array([39, 38, 31, 30])

plt.barh(x, y, height = 0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["maths", "english", "C", "chemistry"])
y = np.array([39, 38, 31, 30])
plt.bar(x, y, width = 0.1)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x = np.array(["maths", "english", "C", "chemistry"])
y = np.array([39, 38, 31, 30])
plt.bar(x, y, color = "#4CAF50")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array(["maths", "english", "C", "chemistry"])
y = np.array([39, 38, 31, 30])
plt.bar(x, y, color = "red")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([25, 48, 35, 45])
mylabels = ["Rachel", "Joey", "Chandler", "Ross"]
mycolors = ["black", "hotpink", "b", "#4CAF50"]

plt.pie(y, labels = mylabels, colors = mycolors)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([25, 48, 35, 45])
mylabels = ["Rachel", "Joey", "Chandler", "Ross"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([25, 48, 35, 45])
mylabels =["Rachel", "Joey", "Chandler", "Ross"]
plt.pie(y, labels = mylabels)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([25, 48, 35, 45])
mylabels = ["Rachel", "Joey", "Chandler", "Ross"]
plt.pie(y, labels = mylabels)
plt.legend(title = " Names:")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([25, 48, 35, 45])
mylabels = ["Rachel", "Joey", "Chandler", "Ross"]

plt.pie(y, labels = mylabels)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]

plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.array([9:10,11:12,13:14,15:16])
y=np.array['Maths','Beee','Python','Chemistry']
x.label='Hours'
y.label='Subjects'
np.plot(x,y,labels)
np.show()
# Out:
#   File "<ipython-input-3-0ca3193b93cb>", line 3
#     x=np.array([9:10,11:12,13:14,15:16])
#                  ^
# SyntaxError: invalid syntax

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35, 25, 25, 15])
mylabels = ["chemistry", "english", "maths", "python"]
myexplode = [0.2, 0, 0, 0]

plt.pie(y, labels = mylabels, explode = myexplode, shadow=True)
plt.show()

# %%
 # Delete the bellow line and write your implementation
f = open(filename)
 k = f.readline()
 k = k.split(' ')
count = 0
for i in k:
   if i in sentiment_words[sentiment_type]:
   count += 1

return count
# Out:
#   File "<ipython-input-19-094cc53f441f>", line 8
#     count += 1
#         ^
# IndentationError: expected an indented block

# %%
f = open(filename)
k = f.readline()
k = k.split(' ')
count = 0
for i in k:
    if i in sentiment_words[sentiment_type]:
      count += 1

return count
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-b5b71f3cdfdd> in <module>()
#       1
# ----> 2 f = open(filename)
#       3 k = f.readline()
#       4 k = k.split(' ')
#       5 count = 0
#
# NameError: name 'filename' is not defined
